# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 2*
#
# ---

# %%
#Instantiate Model
model = LinearRegression()

# %%
#Establish features and target data
features = ['perk_number', 'rooms', 'latitude']
target = ['price']

X_train = train[features]
y_train = train[target]
print(X_train.shape, y_train.shape)

X_test = test[features]
y_test = test[target]
print(X_test.shape, y_train.shape)
# Out:
# (31839, 3) (31839, 1)
# (16973, 3) (31839, 1)

# %%
#Fit model
model.fit(X_train, y_train)
y_train_preds = model.predict(X_train)

# %%
#Test model
y_test_preds = model.predict(X_test)

# %%
#Calculate metrics (r2, mae, mse, rmse) for test data
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_test_preds)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_test_preds)
r2 = r2_score(y_test, y_test_preds)

print(f'This is a linear model built on {features} with latitude filtered to be < 3 sigma.')
print('mean squared error:', mse)
print('root mean squared error:', rmse)
print('mean absolute error:', mae)
print('R^2:', r2)
# Out:
# This is a linear model built on ['perk_number', 'rooms', 'latitude'] with latitude filtered to be < 3 sigma.
# mean squared error: 1671120.3776114173
# root mean squared error: 1292.7182127638712
# mean absolute error: 864.6930334913372
# R^2: 0.4623201601300331

# %% [markdown]
# These new features increase the R^2 by ~4% and reduced MAE by ~40.
